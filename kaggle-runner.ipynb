# %%
# !git clone https://github.com/dncq/Assignment3_NeoPolyps_Segmentation.git

# %%
import os
import requests

url_model = 'https://drive.google.com/u/0/uc?id=1x4ClKqoPC64o4qRdk2y7Q1RSfqwCRP9L&export=download&confirm=t&uuid=d60e69b0-bbbc-4c0d-b2ea-0305efbbf1a0&at=AB6BwCDAamlj_bNrrNRh6sp1QCuV:1700051167458'
save_dir = '/kaggle/working/'

response = requests.get(url_model)


with open(os.path.join(save_dir, 'unet_model.pth'), 'wb') as f:
    f.write(response.content)

# %%
# !mkdir predict_mask

# %%
# !pip install -r /kaggle/working/Assignment3_NeoPolyps_Segmentation/requirement.txt

# %%
# !python /kaggle/working/Assignment3_NeoPolyps_Segmentation/infer.py --checkpoint '/kaggle/working/checkpoint_model.pth' --test_dir '/kaggle/input/bkai-igh-neopolyp/test/test' --predict_dir '/kaggle/working/predict_mask'
